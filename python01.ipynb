# %% [markdown]
# <a href="https://colab.research.google.com/github/Aidai0708/caie-portfolio/blob/Python01/python01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ready")
# Out:
# ready
